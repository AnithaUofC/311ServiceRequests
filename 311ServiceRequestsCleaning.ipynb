# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import pytz

# %%
# Loading the dataset

filename = "311_Service_Requests_2yrs.csv"
df = pd.read_csv(filename)
display(df.head(5))
# Out:
#   service_request_id          requested_date            updated_date  \
# 0        23-00000797  2023/01/02 12:00:00 AM  2023/01/10 12:00:00 AM
# 1        23-00001045  2023/01/02 12:00:00 AM  2024/01/11 12:00:00 AM
# 2        23-00001163  2023/01/02 12:00:00 AM  2023/01/06 12:00:00 AM
# 3        23-00001191  2023/01/02 12:00:00 AM  2024/05/19 12:00:00 AM
# 4        23-00001584  2023/01/02 12:00:00 AM  2023/01/04 12:00:00 AM
#
#               closed_date status_description source  \
# 0  2023/01/10 12:00:00 AM             Closed  Other
# 1  2024/01/11 12:00:00 AM             Closed  Other
# 2  2023/01/06 12:00:00 AM             Closed  Phone
# 3  2023/01/10 12:00:00 AM             Closed  Other
# 4  2023/01/04 12:00:00 AM             Closed  Other
#
#                               service_name  \
# 0  Finance - ONLINE TIPP Agreement Request
# 1        Active Living Program Application
# 2     CN - Registered Social Worker Letter
# 3                       CT - Lost Property
# 4   Recreation - Arena Booking Application
#
#                     agency_responsible  address comm_code comm_name  \
# 0                       CFOD - Finance      NaN       NaN       NaN
# 1  CS - Recreation and Social Programs      NaN       NaN       NaN
# 2          CS - Calgary Neighbourhoods      NaN       NaN       NaN
# 3                 OS - Calgary Transit      NaN       NaN       NaN
# 4              CS - Calgary Recreation      NaN       NaN       NaN
#
#   location_type  longitude  latitude point
# 0           NaN        NaN       NaN   NaN
# 1           NaN        NaN       NaN   NaN
# 2           NaN        NaN       NaN   NaN
# 3           NaN        NaN       NaN   NaN
# 4           NaN        NaN       NaN   NaN

# %%
# Cleaning: Drop rows

df = df.iloc[:1062842]

# %%
#Shape

df.shape
# Out:
# (1062842, 15)

# %%
#Columns

df.columns
# Out:
# Index(['service_request_id', 'requested_date', 'updated_date', 'closed_date',
#        'status_description', 'source', 'service_name', 'agency_responsible',
#        'address', 'comm_code', 'comm_name', 'location_type', 'longitude',
#        'latitude', 'point'],
#       dtype='object')

# %%
#Datatypes

df.dtypes
# Out:
# service_request_id     object
# requested_date         object
# updated_date           object
# closed_date            object
# status_description     object
# source                 object
# service_name           object
# agency_responsible     object
# address               float64
# comm_code              object
# comm_name              object
# location_type          object
# longitude             float64
# latitude              float64
# point                  object
# dtype: object

# %%
# Identifying number of missing values 

missing_values = df.isna().sum()
missing_values
# Out:
# service_request_id          0
# requested_date              0
# updated_date                0
# closed_date             32093
# status_description          0
# source                      0
# service_name                0
# agency_responsible        158
# address               1062842
# comm_code               73834
# comm_name               73833
# location_type           73626
# longitude               73845
# latitude                73845
# point                   73845
# dtype: int64

# %%
# Dropping address column

df = df.drop('address',axis = 1)
df.shape
# Out:
# (1062842, 14)

# %%
# Deriving new columns from requested date

df['requested_date'] = pd.to_datetime(df['requested_date'], format = '%Y/%m/%d %I:%M:%S %p')
print(f"Data type of 'requested_date': {df['requested_date'].dtype}")

df['request_year'] = df['requested_date'].dt.year
df['request_month'] = df['requested_date'].dt.month
df['request_day'] = df['requested_date'].dt.day
# Out:
# Data type of 'requested_date': datetime64[ns]

# %%
df['updated_date'] = pd.to_datetime(df['updated_date'], format = '%Y/%m/%d %I:%M:%S %p')

df['update_year'] = df['updated_date'].dt.year
df['update_month'] = df['updated_date'].dt.month
df['update_day'] = df['updated_date'].dt.day

# %%
# Deriving new columns from requested date

df['closed_date'] = pd.to_datetime(df['closed_date'], format = '%Y/%m/%d %I:%M:%S %p')
print("Dataype:", df['closed_date'].dtype)

# Converting null values to NaT
df['closed_date'] = df['closed_date'].fillna(pd.NaT)


df['closed_year'] = df['closed_date'].dt.year
df['closed_month'] = df['closed_date'].dt.month
df['closed_day'] = df['closed_date'].dt.day

# Replacing null values in derived columns with 0 and converting the column values to int type

df.loc[df['closed_date'].isna(), ['closed_year', 'closed_month', 'closed_day']] = 0
df[['closed_year', 'closed_month', 'closed_day']] = df[['closed_year', 'closed_month', 'closed_day']].astype('Int32')

#display(df.head(5))
# Out:
# Dataype: datetime64[ns]

# %%
# Checking datatypes ofconverted columns

df.dtypes
# Out:
# service_request_id            object
# requested_date        datetime64[ns]
# updated_date          datetime64[ns]
# closed_date           datetime64[ns]
# status_description            object
# source                        object
# service_name                  object
# agency_responsible            object
# comm_code                     object
# comm_name                     object
# location_type                 object
# longitude                    float64
# latitude                     float64
# point                         object
# request_year                   int32
# request_month                  int32
# request_day                    int32
# update_year                    int32
# update_month                   int32
# update_day                     int32
# closed_year                    Int32
# closed_month                   Int32
# closed_day                     Int32
# dtype: object

# %%
# Calculating closing delay and creating new inttype column for closing delay

df['closing_delay'] = df['closed_date'] - df['requested_date']
print("1",df['closing_delay'].dtype)
df['closing_delay'] = df['closing_delay'].dt.days
print(df['closing_delay'].dtype)
df['closing_delay'] = df['closing_delay'].astype('Int64')

print(df['closing_delay'].dtype)

#Check
#df_subset = df.iloc[1050:1116]  # Python slicing includes 150 but excludes 166
#display(df_subset)
# Out:
# 1 timedelta64[ns]
# float64
# Int64

# %%
# Identifying duplicate requests using regex and creating new column 

df['duplicate_request'] = df['status_description'].str.contains(r'Duplicate \(Closed\)', regex=True)

# Convert the boolean values to 'Yes'/'No'
df['duplicate_request'] = df['duplicate_request'].replace({True: 'Yes', False: 'No'})

# Check
#df_subset = df.iloc[150:166]  # Python slicing includes 150 but excludes 166
#display(df_subset)

# %%
# Check max date value in requested_date column

max_value = df['requested_date'].max()
print(max_value)
# Out:
# 2024-12-31 00:00:00

# %%
# Season Categorisation of "Requests"

# Defining Calgary's timezone
calgary_tz = pytz.timezone('America/Edmonton')  

# Exact UTC times for solstices and equinoxes (taken from Govt of Canada Website)

seasons_utc = {
    'Spring_2023': '2023-03-20 21:24:00',
    'Summer_2023': '2023-06-21 14:57:00',
    'Autumn_2023': '2023-09-23 06:50:00',
    'Winter_2023': '2023-12-22 03:27:00',
    'Spring_2024': '2024-03-20 03:06:00',
    'Summer_2024': '2024-06-20 20:50:00',
    'Autumn_2024': '2024-09-22 12:43:00',
    'Winter_2024': '2024-12-21 09:20:00'
}

# Converting the UTC times to Calgary local time

seasons = {}

for season, utc_time_str in seasons_utc.items():
    
    # Converting the UTC string into a datetime object
    
    utc_time = datetime.strptime(utc_time_str, '%Y-%m-%d %H:%M:%S')
    utc_time = pytz.utc.localize(utc_time) 
    
    # Converting to Calgary local time
    local_time = utc_time.astimezone(calgary_tz)
    
    # Saving the result in the dictionary
    seasons[season] = local_time
    
for key, value in seasons.items():
#print(f"{key}: {value.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{key}: {value}")
# Out:
# Spring_2023: 2023-03-20 15:24:00-06:00
# Summer_2023: 2023-06-21 08:57:00-06:00
# Autumn_2023: 2023-09-23 00:50:00-06:00
# Winter_2023: 2023-12-21 20:27:00-07:00
# Spring_2024: 2024-03-19 21:06:00-06:00
# Summer_2024: 2024-06-20 14:50:00-06:00
# Autumn_2024: 2024-09-22 06:43:00-06:00
# Winter_2024: 2024-12-21 02:20:00-07:00

# %%
# Keeping the local time but making it aware for requested_date columns

if df['requested_date'].dt.tz is None:
    df['new_requested_date'] = df['requested_date'].dt.tz_localize('America/Edmonton')

print(df['new_requested_date'].head())
# Out:
# 0   2023-01-02 00:00:00-07:00
# 1   2023-01-02 00:00:00-07:00
# 2   2023-01-02 00:00:00-07:00
# 3   2023-01-02 00:00:00-07:00
# 4   2023-01-02 00:00:00-07:00
# Name: new_requested_date, dtype: datetime64[ns, America/Edmonton]

# %%
# Categorizing into seasons and creating a new 'season' column

# Assigning seasons based on request date

def get_season(request_date):
    for season, season_date in seasons.items():
        if request_date < season_date:
            return season
    return 'Winter_2024'  # Default to the latest season

# Creating new season column 

df['Season'] = df['new_requested_date'].apply(get_season)

display(df)
# Out:
#         service_request_id requested_date updated_date closed_date  \
# 0              23-00000797     2023-01-02   2023-01-10  2023-01-10
# 1              23-00001045     2023-01-02   2024-01-11  2024-01-11
# 2              23-00001163     2023-01-02   2023-01-06  2023-01-06
# 3              23-00001191     2023-01-02   2024-05-19  2023-01-10
# 4              23-00001584     2023-01-02   2023-01-04  2023-01-04
# ...                    ...            ...          ...         ...
# 1062837        24-00979069     2024-12-31   2025-01-27  2025-01-27
# 1062838        24-00978685     2024-12-31   2025-01-21  2025-01-21
# 1062839        24-00977260     2024-12-31   2025-01-21  2025-01-02
# 1062840        24-00978925     2024-12-31   2025-01-21  2025-01-21
# 1062841        24-00977424     2024-12-31   2025-01-22  2025-01-22
#
#         status_description source                             service_name  \
# 0                   Closed  Other  Finance - ONLINE TIPP Agreement Request
# 1                   Closed  Other        Active Living Program Application
# 2                   Closed  Phone     CN - Registered Social Worker Letter
# 3                   Closed  Other                       CT - Lost Property
# 4                   Closed  Other   Recreation - Arena Booking Application
# ...                    ...    ...                                      ...
# 1062837             Closed  Other           DBBS - RIM - Property Research
# 1062838             Closed  Other                 Bylaw - Vehicle Concerns
# 1062839               Open  Other                    WRS - Cart Management
# 1062840             Closed  Other              CT AC - Trip Feedback - CTA
# 1062841             Closed  Other        WRS - Collection Schedule Inquiry
#
#                                         agency_responsible comm_code  \
# 0                                           CFOD - Finance       NaN
# 1                      CS - Recreation and Social Programs       NaN
# 2                              CS - Calgary Neighbourhoods       NaN
# 3                                     OS - Calgary Transit       NaN
# 4                                  CS - Calgary Recreation       NaN
# ...                                                    ...       ...
# 1062837  PDS - Development, Business and Building Services       ASP
# 1062838     CS - Emergency Management and Community Safety       TEM
# 1062839                  OS - Waste and Recycling Services       HUN
# 1062840                               OS - Calgary Transit       DNW
# 1062841                  OS - Waste and Recycling Services       SET
#
#                  comm_name  ... update_year  update_month  update_day  \
# 0                      NaN  ...        2023             1          10
# 1                      NaN  ...        2024             1          11
# 2                      NaN  ...        2023             1           6
# 3                      NaN  ...        2024             5          19
# 4                      NaN  ...        2023             1           4
# ...                    ...  ...         ...           ...         ...
# 1062837        ASPEN WOODS  ...        2025             1          27
# 1062838             TEMPLE  ...        2025             1          21
# 1062839   HUNTINGTON HILLS  ...        2025             1          21
# 1062840  DOWNTOWN WEST END  ...        2025             1          21
# 1062841              SETON  ...        2025             1          22
#
#         closed_year  closed_month  closed_day  closing_delay  \
# 0              2023             1          10              8
# 1              2024             1          11            374
# 2              2023             1           6              4
# 3              2023             1          10              8
# 4              2023             1           4              2
# ...             ...           ...         ...            ...
# 1062837        2025             1          27             27
# 1062838        2025             1          21             21
# 1062839        2025             1           2              2
# 1062840        2025             1          21             21
# 1062841        2025             1          22             22
#
#          duplicate_request        new_requested_date       Season
# 0                       No 2023-01-02 00:00:00-07:00  Spring_2023
# 1                       No 2023-01-02 00:00:00-07:00  Spring_2023
# 2                       No 2023-01-02 00:00:00-07:00  Spring_2023
# 3                       No 2023-01-02 00:00:00-07:00  Spring_2023
# 4                       No 2023-01-02 00:00:00-07:00  Spring_2023
# ...                    ...                       ...          ...
# 1062837                 No 2024-12-31 00:00:00-07:00  Winter_2024
# 1062838                 No 2024-12-31 00:00:00-07:00  Winter_2024
# 1062839                 No 2024-12-31 00:00:00-07:00  Winter_2024
# 1062840                 No 2024-12-31 00:00:00-07:00  Winter_2024
# 1062841                 No 2024-12-31 00:00:00-07:00  Winter_2024
#
# [1062842 rows x 27 columns]

# %%
# Closed requests taken into account

statistics_closing_delay = df['closing_delay'].describe()
print(statistics_closing_delay)
# Out:
# count    1030749.0
# mean     12.630157
# std      39.587334
# min            0.0
# 25%            1.0
# 50%            3.0
# 75%            8.0
# max          740.0
# Name: closing_delay, dtype: Float64

# %%
# Checking no of empty values in 'closing_delay' column

na_count = df['closing_delay'].isna().sum()
print(na_count)
# Out:
# 32093

# %%
# Checking number of open requests 

no_open_requests = len(df[df['status_description'] == 'Open'])
no_open_requests
# Out:
# 32781

# %%
# Finding data discrepencies (688 numbers because the missing values in closed_dates was found to be 32093)

filtered_df = df[df['status_description'] == 'Open' ]
grouped_data = filtered_df.groupby('status_description')['closed_date']
pd.set_option('display.max_rows', None)
#display(grouped_data.tail(200))

# %%
# To solve this data discrepency, change the "status" of requests with closed dates to "Closed".

df['modified_status'] = df.apply(
   lambda row: 'Closed' if pd.notna(row['closed_date']) and row['status_description'] == 'Open' 
    else ('Duplicate (Closed)' if pd.notna(row['closed_date']) and row['status_description'] == 'Duplicate (Open)' 
          else row['status_description']), axis=1
)
display(df.tail(20))
# Out:
#         service_request_id requested_date updated_date closed_date  \
# 1062822        24-00977737     2024-12-31   2025-01-22         NaT
# 1062823        24-00978707     2024-12-31   2025-01-27  2025-01-27
# 1062824        24-00977730     2024-12-31   2025-01-24         NaT
# 1062825        24-00977092     2024-12-31   2025-01-21  2025-01-21
# 1062826        24-00979193     2024-12-31   2025-01-21  2025-01-21
# 1062827        24-00979009     2024-12-31   2025-01-23  2025-01-23
# 1062828        24-00979145     2024-12-31   2025-01-21  2025-01-21
# 1062829        24-00979001     2024-12-31   2025-01-21  2025-01-21
# 1062830        24-00979129     2024-12-31   2025-01-23  2025-01-23
# 1062831        24-00977902     2024-12-31   2025-01-21  2025-01-07
# 1062832        24-00978105     2024-12-31   2025-01-22         NaT
# 1062833        24-00977888     2024-12-31   2025-01-21  2025-01-21
# 1062834        24-00978258     2024-12-31   2025-01-21  2025-01-21
# 1062835        24-00978284     2024-12-31   2025-01-21  2025-01-21
# 1062836        24-00977541     2024-12-31   2025-01-27  2025-01-27
# 1062837        24-00979069     2024-12-31   2025-01-27  2025-01-27
# 1062838        24-00978685     2024-12-31   2025-01-21  2025-01-21
# 1062839        24-00977260     2024-12-31   2025-01-21  2025-01-02
# 1062840        24-00978925     2024-12-31   2025-01-21  2025-01-21
# 1062841        24-00977424     2024-12-31   2025-01-22  2025-01-22
#
#         status_description source  \
# 1062822               Open  Other
# 1062823             Closed  Other
# 1062824               Open  Other
# 1062825             Closed  Other
# 1062826             Closed  Other
# 1062827             Closed    App
# 1062828             Closed  Other
# 1062829             Closed  Other
# 1062830             Closed  Other
# 1062831             Closed  Other
# 1062832               Open  Other
# 1062833             Closed  Other
# 1062834             Closed  Other
# 1062835             Closed  Other
# 1062836             Closed  Other
# 1062837             Closed  Other
# 1062838             Closed  Other
# 1062839               Open  Other
# 1062840             Closed  Other
# 1062841             Closed  Other
#
#                                               service_name  \
# 1062822                  Active Living Program Application
# 1062823                  Active Living Program Application
# 1062824             Parks - Parks and Open Spaces Bookings
# 1062825  VFH - Taxi/Limousine/TNC (Ride Sharing) Concer...
# 1062826                Bylaw - Material on Public Property
# 1062827       Bylaw - Disturbance and Behavioural Concerns
# 1062828                              UEP - Odour Inquiries
# 1062829                          WATS - Water Meter Issues
# 1062830                  Roads - Signs - Missing - Damaged
# 1062831              AS - No Control Dog in Off Leash Area
# 1062832                  WRS - Collection Schedule Inquiry
# 1062833                CT - Park and Ride Lot - LRT or Bus
# 1062834                           Bylaw - Vehicle Concerns
# 1062835                           Bylaw - Vehicle Concerns
# 1062836                             Roads - Detour Inquiry
# 1062837                     DBBS - RIM - Property Research
# 1062838                           Bylaw - Vehicle Concerns
# 1062839                              WRS - Cart Management
# 1062840                        CT AC - Trip Feedback - CTA
# 1062841                  WRS - Collection Schedule Inquiry
#
#                                         agency_responsible comm_code  \
# 1062822                CS - Recreation and Social Programs       NaN
# 1062823                CS - Recreation and Social Programs       NaN
# 1062824                         OS - Parks and Open Spaces       NaN
# 1062825     CS - Emergency Management and Community Safety       NaN
# 1062826     CS - Emergency Management and Community Safety       CAN
# 1062827     CS - Emergency Management and Community Safety       HOR
# 1062828                                OS - Water Services       BED
# 1062829                                OS - Water Services       SAD
# 1062830                                      OS - Mobility       ABP
# 1062831     CS - Emergency Management and Community Safety       REN
# 1062832                  OS - Waste and Recycling Services       SET
# 1062833                               OS - Calgary Transit       SUN
# 1062834     CS - Emergency Management and Community Safety       PAN
# 1062835     CS - Emergency Management and Community Safety       PAN
# 1062836                                      OS - Mobility       BLN
# 1062837  PDS - Development, Business and Building Services       ASP
# 1062838     CS - Emergency Management and Community Safety       TEM
# 1062839                  OS - Waste and Recycling Services       HUN
# 1062840                               OS - Calgary Transit       DNW
# 1062841                  OS - Waste and Recycling Services       SET
#
#                     comm_name  ... update_month  update_day  closed_year  \
# 1062822                   NaN  ...            1          22            0
# 1062823                   NaN  ...            1          27         2025
# 1062824                   NaN  ...            1          24            0
# 1062825                   NaN  ...            1          21         2025
# 1062826        CANYON MEADOWS  ...            1          21         2025
# 1062827               HORIZON  ...            1          23         2025
# 1062828    BEDDINGTON HEIGHTS  ...            1          21         2025
# 1062829          SADDLE RIDGE  ...            1          21         2025
# 1062830  AURORA BUSINESS PARK  ...            1          23         2025
# 1062831               RENFREW  ...            1          21         2025
# 1062832                 SETON  ...            1          22            0
# 1062833              SUNRIDGE  ...            1          21         2025
# 1062834        PANORAMA HILLS  ...            1          21         2025
# 1062835        PANORAMA HILLS  ...            1          21         2025
# 1062836              BELTLINE  ...            1          27         2025
# 1062837           ASPEN WOODS  ...            1          27         2025
# 1062838                TEMPLE  ...            1          21         2025
# 1062839      HUNTINGTON HILLS  ...            1          21         2025
# 1062840     DOWNTOWN WEST END  ...            1          21         2025
# 1062841                 SETON  ...            1          22         2025
#
#         closed_month  closed_day  closing_delay  duplicate_request  \
# 1062822            0           0           <NA>                 No
# 1062823            1          27             27                 No
# 1062824            0           0           <NA>                 No
# 1062825            1          21             21                 No
# 1062826            1          21             21                 No
# 1062827            1          23             23                 No
# 1062828            1          21             21                 No
# 1062829            1          21             21                 No
# 1062830            1          23             23                 No
# 1062831            1           7              7                 No
# 1062832            0           0           <NA>                 No
# 1062833            1          21             21                 No
# 1062834            1          21             21                 No
# 1062835            1          21             21                 No
# 1062836            1          27             27                 No
# 1062837            1          27             27                 No
# 1062838            1          21             21                 No
# 1062839            1           2              2                 No
# 1062840            1          21             21                 No
# 1062841            1          22             22                 No
#
#                new_requested_date       Season  modified_status
# 1062822 2024-12-31 00:00:00-07:00  Winter_2024             Open
# 1062823 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062824 2024-12-31 00:00:00-07:00  Winter_2024             Open
# 1062825 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062826 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062827 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062828 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062829 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062830 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062831 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062832 2024-12-31 00:00:00-07:00  Winter_2024             Open
# 1062833 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062834 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062835 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062836 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062837 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062838 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062839 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062840 2024-12-31 00:00:00-07:00  Winter_2024           Closed
# 1062841 2024-12-31 00:00:00-07:00  Winter_2024           Closed
#
# [20 rows x 28 columns]

# %%
summary = df['status_description'].value_counts()
print(summary)
# Out:
# status_description
# Closed                1019672
# Open                    32781
# Duplicate (Closed)       9049
# Duplicate (Open)         1340
# Name: count, dtype: int64

# %%
summary1 = df['modified_status'].value_counts()
print(summary1)
# Out:
# modified_status
# Closed                1021695
# Open                    30758
# Duplicate (Closed)       9054
# Duplicate (Open)         1335
# Name: count, dtype: int64
